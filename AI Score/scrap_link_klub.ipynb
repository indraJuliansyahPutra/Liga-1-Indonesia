# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import pandas as pd

chrome_driver_path = 'D:\Project\Liga 1 Indonesia\Liga-1-Indonesia\chromedriver-win64\chromedriver.exe'


# Setup Driver
options = webdriver.ChromeOptions()
#options.add_argument("--headless") # Biar Chrome-nya tidak dibuka (Jalan di belakang)
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window() # Kalo headless, ini nggak berguna

url = "https://www.aiscore.com/id/tournament-indonesian-liga-1/2jr7owijlrf1q0e/standings"

driver.get(url)
time.sleep(2)

link_klub_elements = driver.find_elements(By.XPATH, '/html/body/div/div/div/div[3]/div[2]/div[3]/div[1]/div[1]/div/div[1]/div/div/div[3]/div/div/div/div[1]/a')
link_klub = [element.get_attribute('href') for element in link_klub_elements]
print(link_klub)
# Out:
# ['https://www.aiscore.com/id/team-persib-bandung/wv78xiplgnfnkrj', 'https://www.aiscore.com/id/team-dewa-united-fc/69759i5z0nsnk23', 'https://www.aiscore.com/id/team-persebaya-surabaya/g6763ide4mfp7ry', 'https://www.aiscore.com/id/team-malut-united/g6763iep85ap7ry', 'https://www.aiscore.com/id/team-bali-united/l6kegix3j3fg75d', 'https://www.aiscore.com/id/team-persija-jakarta/m2q15i2d9wfm76x', 'https://www.aiscore.com/id/team-borneo-fc/wv78xid3j8hnkrj', 'https://www.aiscore.com/id/team-psm-makassar/jek33i6688fdko2', 'https://www.aiscore.com/id/team-psbs-biak-numfor-/j374oid5xmtrqo6', 'https://www.aiscore.com/id/team-arema-fc/zrkn6im2vmcnqle', 'https://www.aiscore.com/id/team-persita-tangerang/jek33ij34msdko2', 'https://www.aiscore.com/id/team-persik-kediri/jr7owi61pet3q0e', 'https://www.aiscore.com/id/team-madura-united/527r3i9wd9h87ev', 'https://www.aiscore.com/id/team-persis-solo-fc/vmqy9i0p90a4k9r', 'https://www.aiscore.com/id/team-barito-putera/g6763id0dgip7ry', 'https://www.aiscore.com/id/team-semen-padang/o17pjir15wh27jw', 'https://www.aiscore.com/id/team-psis-semarang/wv78xid3rjbnkrj', 'https://www.aiscore.com/id/team-pss-sleman/m2q15ier5jfm76x']

# %%
print(len(link_klub))
# Out:
# 18

# %%
data_link_klub = pd.DataFrame(link_klub, columns=['Link Klub'])
data_link_klub
# Out:
#                                             Link Klub
# 0   https://www.aiscore.com/id/team-persib-bandung...
# 1   https://www.aiscore.com/id/team-dewa-united-fc...
# 2   https://www.aiscore.com/id/team-persebaya-sura...
# 3   https://www.aiscore.com/id/team-malut-united/g...
# 4   https://www.aiscore.com/id/team-bali-united/l6...
# 5   https://www.aiscore.com/id/team-persija-jakart...
# 6   https://www.aiscore.com/id/team-borneo-fc/wv78...
# 7   https://www.aiscore.com/id/team-psm-makassar/j...
# 8   https://www.aiscore.com/id/team-psbs-biak-numf...
# 9   https://www.aiscore.com/id/team-arema-fc/zrkn6...
# 10  https://www.aiscore.com/id/team-persita-tanger...
# 11  https://www.aiscore.com/id/team-persik-kediri/...
# 12  https://www.aiscore.com/id/team-madura-united/...
# 13  https://www.aiscore.com/id/team-persis-solo-fc...
# 14  https://www.aiscore.com/id/team-barito-putera/...
# 15  https://www.aiscore.com/id/team-semen-padang/o...
# 16  https://www.aiscore.com/id/team-psis-semarang/...
# 17  https://www.aiscore.com/id/team-pss-sleman/m2q...

# %%
data_link_klub.to_csv('Link_Klub.csv', index=False)
print("Sudah disimpan")
# Out:
# Sudah disimpan
